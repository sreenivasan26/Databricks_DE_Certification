# %%
print("Hello world")

# %%
# %sql
SELECT "Hello world from SQL";

# %% [markdown]
# # Section header
# Find the header in table of contents

# %%
variable = "This variable is from magic commands file"
